# %%
#assignment.1  feroz noor


print('Name:\tFeroz noor')
print("Father name:\t[Noor jan]")
print("Date of birth:\t[03.12.2006]")
# Out:
# Name:	Feroz noor
# Father name:	[Noor jan]
# Date of birth:	[03.12.2006]

# %%
#assignment.2 feroz noor


Name = "Feroz noor"
Age = 20
Education = "Bs computer science"
Country = "Pakistan"

print("Name:\t", Name)
print("Age:\t", Age)
print("Education:\t", Education)
print("Country:\t", Country)
# Out:
# Name:	 Feroz noor
# Age:	 20
# Education:	 Bs computer science
# Country:	 Pakistan

# %%
# assignment.3  feroz noor

a = 5
b = 10

# arithmetic operations
print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)

# comparison operations
print("Greater than:", a > b)
print("Less than:", a < b)
print("Equal:", a == b)
print("Not equal:", a != b)
# Out:
# Addition: 15
# Subtraction: -5
# Multiplication: 50
# Division: 0.5
# Greater than: False
# Less than: True
# Equal: False
# Not equal: True

# %%
#Assignment.4  feroz noor

english_marks = 70
math_marks = 60
islamiat_marks = 65

total_marks = 300

obtained_marks = english_marks + math_marks + islamiat_marks
percentage = (obtained_marks / total_marks) * 100

print("english_marks:\t", english_marks)
print("math_marks:\t", math_marks)
print("islamiat_marks:\t", islamiat_marks)
print("obtained_marks:\t", obtained_marks)
print("percentage:\t", percentage)
# Out:
# english_marks:	 70
# math_marks:	 60
# islamiat_marks:	 65
# obtained_marks:	 195
# percentage:	 65.0

# %%
#assignment.5  feroz noor


a = 10
b = 20

print("Before swapping:")
print("a =", a)
print("b =", b)

a, b = b, a

print("After swapping:")
print("a =", a) 
print("b =", b)
# Out:
# Before swapping:
# a = 10
# b = 20
# After swapping:
# a = 20
# b = 10

# %%
#assignment.6  feroz noor

radius = 5
pi = 3.14

area = pi * radius ** 2
circumference = 2 * pi * radius

print("Radius:", radius)
print("Circumference of the circle:", circumference)
print("Area of circle:", area)
# Out:
# Radius: 5
# Circumference of the circle: 31.400000000000002
# Area of circle: 78.5

# %%
#assignment.7  feroz noor

price = 100
discount_percentage = 13

discount_amount = (price * discount_percentage) / 100
final_price = price - discount_amount

print("Price:\t", price)
print("Discount percentage:\t", discount_percentage) 
print("Discount amount:\t", discount_amount)
print("Final price:\t", final_price)
# Out:
# Price:	 100
# Discount percentage:	 13
# Discount amount:	 13.0
# Final price:	 87.0
